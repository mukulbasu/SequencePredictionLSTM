# %%
# Ignore this cell.. Just some standard stuff I do

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.mixed_precision import experimental as mixed_precision
import os

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))

gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=(1024*6))])
#tf.debugging.set_log_device_placement(True)
#policy = mixed_precision.Policy('mixed_float16')
#mixed_precision.set_policy(policy)
# Out:
# 2.2.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Sample code for generating sequences for pose

import random
import numpy as np


ARCHS = ["lstm", "gru"]#["lstm", "gru"]
DATA_SEQUENCE = True
DATAPOINTS = 32*500 #Controls the number of rows of datasets to be generated (For some reason, this needs to be a multiple of 32)
MAX_NUM_FRAMES_PER_POSE = 50 #50 #This is the number of frames that can detect one pose. Like a pose hold of 1 sec can result in 10 frames of one pose
NUM_POSES = 7
REP = [0, 1, 2, 3, 4, 5, 6, 2, 1, 0]
MAX_SEQ_SIZE = 32*100 #Number of columns 
inputs = np.empty([DATAPOINTS, MAX_SEQ_SIZE, NUM_POSES], np.int32) # Format: 3D array: Row index, Column, (0 index for input, 1 index for total number of poses in sequence)
targets = np.empty([DATAPOINTS, MAX_SEQ_SIZE], np.float32) # Format: 2D array: Row index, Column

# %%
# load numpy array from npz file
from numpy import load
inputs = load('inputs.npz')['arr_0']
targets = load('targets.npz')['arr_0']
targets = (targets*10).astype(int)
print(targets[0][100])
# Out:
# 4

# %%
import collections
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Embedding, Dropout, TimeDistributed, GRU, SimpleRNN
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import argparse

batches = 32
def get_model(seq_size, arch, batch):
    if arch == "lstm":
        hidden_size = 20
        model = Sequential()
        model.add(LSTM(hidden_size, batch_input_shape=(batch, seq_size, NUM_POSES), return_sequences=True, stateful=True))
        model.add(TimeDistributed(Dense(1)))
    elif arch == "gru":
        hidden_size = 20
        model = Sequential()
        model.add(GRU(hidden_size, input_shape=(seq_size, NUM_POSES), return_sequences=True))
        model.add(TimeDistributed(Dense(1)))
    return model

training_models = {}
prediction_models = {}
for arch in ARCHS:
    training_models[arch] = get_model(MAX_SEQ_SIZE, arch, batches)

# %%
targets.shape
print(targets[0][200])
print(inputs[0][200])
# Out:
# 3
# [0 0 1 0 0 0 0]

# %%
from tensorflow.keras.utils import Sequence
from numpy import load
import math

class DataSequence(Sequence):
    def __init__(self, batch_size):
        self.batch_size = batch_size        
        self.inputs = load('inputs.npz')['arr_0']
        self.targets = load('targets.npz')['arr_0']
        self.targets = (self.targets*10).astype(int)
    
    def __len__(self):
        return math.ceil(self.inputs.shape[0]/self.batch_size)
        
    def __getitem__(self, idx):
        batch_x = self.inputs[idx * self.batch_size: (idx+1)* self.batch_size]
        batch_y = self.targets[idx * self.batch_size: (idx+1)* self.batch_size]
        return np.array(batch_x), np.array(batch_y)

# %%
# model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), optimizer='adam', metrics=['categorical_accuracy'])
print(targets[0][200])
for arch in ARCHS:
    optimizer = keras.optimizers.Adam(lr=0.001)
    training_models[arch].compile(optimizer=optimizer,
                  loss='mean_squared_error',
                  metrics=['mean_squared_error'])
    if (DATA_SEQUENCE):
        training_models[arch].fit(DataSequence(batches), batch_size=batches, epochs=15, verbose=1)
    else:
        training_models[arch].fit(inputs, targets, batch_size=batches, epochs=15, verbose=1)
    training_models[arch].reset_states()
# Out:
# 3
# Epoch 1/15
# 500/500 [==============================] - 34s 68ms/step - loss: 7.1793 - mean_squared_error: 7.1793
# Epoch 2/15
# 500/500 [==============================] - 34s 67ms/step - loss: 3.4328 - mean_squared_error: 3.4328
# Epoch 3/15
# 500/500 [==============================] - 34s 67ms/step - loss: 2.9887 - mean_squared_error: 2.9887
# Epoch 4/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.8340 - mean_squared_error: 2.8340
# Epoch 5/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.7706 - mean_squared_error: 2.7706
# Epoch 6/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.7383 - mean_squared_error: 2.7383
# Epoch 7/15
# 500/500 [==============================] - 34s 67ms/step - loss: 2.7069 - mean_squared_error: 2.7069
# Epoch 8/15
# 500/500 [==============================] - 34s 67ms/step - loss: 2.6847 - mean_squared_error: 2.6847
# Epoch 9/15
# 500/500 [==============================] - 34s 67ms/step - loss: 2.6709 - mean_squared_error: 2.6709
# Epoch 10/15
# 500/500 [==============================] - 34s 67ms/step - loss: 2.6487 - mean_squared_error: 2.6487
# Epoch 11/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.6369 - mean_squared_error: 2.6369
# Epoch 12/15
# 500/500 [==============================] - 34s 67ms/step - loss: 2.6197 - mean_squared_error: 2.6197
# Epoch 13/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.6116 - mean_squared_error: 2.6116
# Epoch 14/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.5983 - mean_squared_error: 2.5983
# Epoch 15/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.5909 - mean_squared_error: 2.5909
# Epoch 1/15
# 500/500 [==============================] - 34s 69ms/step - loss: 6.8246 - mean_squared_error: 6.8246
# Epoch 2/15
# 500/500 [==============================] - 34s 69ms/step - loss: 3.1728 - mean_squared_error: 3.1728
# Epoch 3/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.7855 - mean_squared_error: 2.7855
# Epoch 4/15
# 500/500 [==============================] - 35s 70ms/step - loss: 2.6985 - mean_squared_error: 2.6985
# Epoch 5/15
# 500/500 [==============================] - 35s 69ms/step - loss: 2.6578 - mean_squared_error: 2.6578
# Epoch 6/15
# 500/500 [==============================] - 35s 70ms/step - loss: 2.6278 - mean_squared_error: 2.6278
# Epoch 7/15
# 500/500 [==============================] - 34s 69ms/step - loss: 2.6050 - mean_squared_error: 2.6050
# Epoch 8/15
# 500/500 [==============================] - 34s 69ms/step - loss: 2.5907 - mean_squared_error: 2.5907
# Epoch 9/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.5743 - mean_squared_error: 2.5743
# Epoch 10/15
# 500/500 [==============================] - 35s 69ms/step - loss: 2.5614 - mean_squared_error: 2.5614
# Epoch 11/15
# 500/500 [==============================] - 35s 70ms/step - loss: 2.5462 - mean_squared_error: 2.5462
# Epoch 12/15
# 500/500 [==============================] - 35s 69ms/step - loss: 2.5317 - mean_squared_error: 2.5317
# Epoch 13/15
# 500/500 [==============================] - 34s 68ms/step - loss: 2.5191 - mean_squared_error: 2.5191
# Epoch 14/15
# 500/500 [==============================] - 35s 70ms/step - loss: 2.5043 - mean_squared_error: 2.5043
# Epoch 15/15
# 500/500 [==============================] - 35s 69ms/step - loss: 2.4828 - mean_squared_error: 2.4828

# %%
# print(targets[0][200])
# for arch in ARCHS:
#     optimizer = keras.optimizers.Adam(lr=0.00001)
#     training_models[arch].compile(optimizer=optimizer,
#                   loss='mean_squared_error',
#                   metrics=['mean_squared_error'])
#     training_models[arch].fit(inputs, targets, batch_size=batches, epochs=15, verbose=1)
#     training_models[arch].reset_states()

# %%
# probability_model = tf.keras.Sequential([model, 
#                                          tf.keras.layers.Softmax()])
# print(inputs[0][0].shape)
# predictions = model.predict(inputs, verbose=0)

# %%
for arch in ARCHS:
    print(arch)
    training_models[arch].save_weights(arch+'_model.h5')

import time
time.sleep(2)
# Out:
# lstm
# gru

# %%
import matplotlib.pyplot as plt
predModel = {}
for arch in ARCHS:
    predModel[arch] = get_model(1, arch, 1)
    predModel[arch].load_weights(arch+'_model.h5')

for k in range(2):
    j = random.randint(0, inputs.shape[0]-2)
    plot_inputs = np.empty(inputs.shape[1])
    plot_preds = {}
    for arch in ARCHS:
        plot_preds[arch] = np.empty(inputs.shape[1])
        
    plot_preds["pred"] = np.empty(inputs.shape[1])
    plot_targets = np.empty(inputs.shape[1])
    
    for arch in ARCHS:
        for i in range(inputs.shape[1]-1):
            predictions = predModel[arch].predict(inputs[j:j+1, i:i+1], verbose=0)
            #print(predictions)
            plot_preds["pred"][i] = (predictions[0][0]).astype(int)
        plt.plot(plot_preds["pred"], color='g', linestyle='--', label=arch)
        plt.plot(targets[j], color='r', linestyle='dotted', label="target")
        plt.plot(np.argmax(inputs[j:j+1], axis=2)[0], color='b', label="input")
        plt.rcParams["figure.figsize"] = (40,6)
        plt.legend()
        plt.xlabel(arch)
        plt.show()

# %%
print(training_models["lstm"].summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (32, 3200, 20)            2240
# _________________________________________________________________
# time_distributed (TimeDistri (32, 3200, 1)             21
# =================================================================
# Total params: 2,261
# Trainable params: 2,261
# Non-trainable params: 0
# _________________________________________________________________
# None
